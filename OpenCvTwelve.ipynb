# %%
#hist->continos distrtuin of data's freq 
#we can use this to show freq of the 3 chnnel and how they get changed 
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dark_horse=cv2.imread('s.jpeg')  #bgr
show_horse=cv2.cvtColor(dark_horse,cv2.COLOR_BGR2RGB)

rainbow=cv2.imread('ss.png')
show_rainbow=cv2.cvtColor(rainbow,cv2.COLOR_BGR2RGB)

blue_bricks=cv2.imread('cat.jpg')
show_bricks=cv2.cvtColor(blue_bricks,cv2.COLOR_BGR2RGB)

plt.imshow(show_horse)

# %%
hist_values=cv2.calcHist([blue_bricks],channels=[0],mask=None,histSize=[256],ranges=[0,256])
hist_values.shape
plt.plot(hist_values)

# %%
mask=np.zeros(rainbow.shape[:2],np.uint8)  #2d image req only 
plt.imshow(mask,cmap='gray')
mask[300:400,100:400]
plt.imshow(mask,cmap='gray')
