# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


def load_img():
    img=cv2.imread('ss.png').astype(np.float32)/255
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    return img

#load_img()


def display_img(img):
    fig=plt.figure(figsize=(12,10))
    ax=fig.add_subplot(111)
    ax.imshow(img)

i=load_img()
display_img(i)

# %%
gamama=1/4
result=np.power(i,gamama)  #rise every ixel value to poer
display_img(result)

# %%
img=load_img()
font=cv2.FONT_HERSHEY_COMPLEX
cv2.putText(img,text= 'bricks',org=(10,600),fontFace=font,fontScale=10,color=(255,0,0),thickness=4)
display_img(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
kernel=np.ones(shape=(5,5),dtype=np.float32)/25
dst=cv2.filter2D(img,-1)
display_img(dest)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 2
#       1 kernel=np.ones(shape=(5,5),dtype=np.float32)/25
# ----> 2 dst=cv2.filter2D(img,-1)
#       3 display_img(dest)
#
# error: OpenCV(4.8.0) :-1: error: (-5:Bad argument) in function 'filter2D'
# > Overload resolution failed:
# >  - filter2D() missing required argument 'kernel' (pos 3)
# >  - filter2D() missing required argument 'kernel' (pos 3)

# %%
blurred_img=cv2.GaussianBlur(img,(5,5),10)
display_img(blurred_img)  #many more blurred functions
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
noise_img=cv2.imread('ss.png')
display_img(noise_img)

# %%
median=cv2.medianBlur(noise_img,5)  #reduces noise in image 
display_img(median)
