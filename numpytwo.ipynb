# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline   
 #dipaplying plots and images i ntbook

from PIL import Image

pic=Image.open('ss.png')
display(pic)
type(pic)  #pil image png file
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080 at 0x23F0130E100>
# PIL.PngImagePlugin.PngImageFile

# %%
pic_arr=np.asarray(pic)
type(pic_arr)  #no array
pic_arr.shape      
# 1080,1920,4
plt.imshow(pic_arr)

# %%
print(pic_arr)
# Out:
# [[[  3   3   3 255]
#   [  3   3   3 255]
#   [  3   3   3 255]
#   ...
#   [  3   3   3 255]
#   [  3   3   3 255]
#   [  3   3   3 255]]
#
#  [[  3   3   3 255]
#   [  3   3   3 255]
#   [  3   3   3 255]
#   ...
#   [  3   3   3 255]
#   [  3   3   3 255]
#   [  3   3   3 255]]
#
#  [[  3   3   3 255]
#   [  3   3   3 255]
#   [  3   3   3 255]
#   ...
#   [  3   3   3 255]
#   [  3   3   3 255]
#   [  3   3   3 255]]
#
#  ...
#
#  [[219 217 224 255]
#   [219 217 224 255]
#   [220 218 225 255]
#   ...
#   [218 218 218 255]
#   [216 216 216 255]
#   [216 216 216 255]]
#
#  [[220 218 225 255]
#   [217 215 222 255]
#   [218 216 223 255]
#   ...
#   [217 217 217 255]
#   [217 217 217 255]
#   [218 218 218 255]]
#
#  [[219 217 224 255]
#   [220 218 225 255]
#   [219 217 224 255]
#   ...
#   [219 219 219 255]
#   [218 218 218 255]
#   [217 217 217 255]]]

# %%
pic_red=pic_arr.copy()
pic_red[:,:,3]    #r all g all bule only forst 

#red channel values 
plt.imshow(pic_red[:,:,0],cmap= 'gray')  #red celss value -->jidhar dark red->whiish and jidhar light waha gray 
pic_red[:,:,1] =0  #making all red channels =0
