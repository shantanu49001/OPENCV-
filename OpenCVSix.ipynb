# %%
#rgb   older version
#hsl and hsv new vrsiosn of image colors

#rgb cuvbl model
#hsl-> cyclidrical     all around cyclinder has all colours ligness howbbright it is required 
#hsv me ligness ki jagah value hai 

#cvtcolor-->for colour spaces 
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
img=cv2.imread('ss.png')
plt.imshow(img)    #not coded properly
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)    #bgr to rgb 
plt.imshow(img)
img=cv2.cvtColor(img,cv2.COLOR_RGB2HSV)  #now it's different coloured 
plt.imshow(img)
