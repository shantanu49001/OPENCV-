# %%
#on user press seprate the eleemts 
#code error
#code error
#code error
#code error
#code error
#code error
#code error
#code error

import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
road=cv2.imread('pic.jpg')
road_copy=np.copy(road)
plt.imshow(road)

# %%
road.shape[:2]
# Out:
# (1080, 1920)

# %%
marker_image=np.zeros(road.shape[:2],dtype=np.int32)
segments=np.zeros(road.shape,dtype=np.uint8)
marker_image.shape
# Out:
# (1080, 1920)

# %%
segments.shape
# Out:
# (1080, 1920, 3)

# %%
#colour mapping import 
from matplotlib import cm

def create_rgb(i):
    return tuple(np.array(cm.tab10(i)[:3]) * 255)

# %%
#take list of colours
colours = []
for i in range(10):
    colours[i]=create_rgb(i)


#colours
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       2 colours = []
#       3 for i in range(10):
# ----> 4     colours[i]=create_rgb(i)
#       7 #colours
#
# Cell In[13], line 5, in create_rgb(i)
#       4 def create_rgb(i):
# ----> 5     return tuple(np.array(cm.tab10(i)[:3]) * 255)
#
# TypeError: 'numpy.ndarray' object is not callable
