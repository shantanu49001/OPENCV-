# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2
img=cv2.imread('ss.png')  #opencv directly converts it to tge numpy array 
type(img)

#open cv me agar path galat diya to errro nhi ata null assign ho jata hai 
img
img.shape  # 1080 ,1920 ,3
plt.imshow(img)    #matplot lib and opencv expetes different order of rgb order 
#mplt  r,g,b
#opencv   bgr
fix_ing=cv2.cvtColor(img,cv2.COLOR_BGRA2RGB)  
plt.show(fix_ing)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 12
#       9 #mplt  r,g,b
#      10 #opencv   bgr
#      11 fix_ing=cv2.cvtColor(img,cv2.COLOR_BGRA2RGB)
# ---> 12 plt.show(fix_ing)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib_inline\backend_inline.py:98, in show(close, block)
#      95 show._to_draw = []
#      96 # only call close('all') if any to close
# ...

# %%
img_gray=cv2.imread('ss.png',cv2.IMREAD_GRAYSCALE)
img_gray.shape  #no need of 3 channels now 
img_gray.min
img_gray.max

new_img=cv2.resize(img_gray,(1000,400))
plt.imshow(new_img)

# %%
w_ratio=0.5
h_ratio=0.5

new_iimg=cv2.resize(fix_ing,(0,0),fix_ing,w_ratio,h_ratio)
plt.imshow(new_iimg)

# %%
neew_img=cv2.flip(fix_ing,0)  #hoeix flip
plt.imshow(neew_img)

# %%
cv2.imwrite('totally_new',neew_img)

fig=plt.figure(figsize=(2,2))
ax=fig.add_subplot(111)
ax.imshow(fix_ing)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 cv2.imwrite('totally_new',neew_img)
#       3 fig=plt.figure(figsize=(2,2))
#       4 ax=fig.add_subplot(111)
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:696: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'cv::imwrite_'
